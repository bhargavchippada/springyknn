# %%
from springyknn.springyknn import *

# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
from sklearn.datasets import load_breast_cancer
x_train, y_train = load_breast_cancer(True)
y_train = y_train.reshape(-1,1)
print(x_train.shape)
print(y_train.shape)
# Out:
# (569, 30)
# (569, 1)

# %%
springyknn = SpringyKNN(x_train, y_train, randomize=True, num_pivots=569)
G = springyknn.get_springy_knn_graph(k1=5, k2=5)
springyknn.write_gexf(G, filename='breast_cancer_springyknn_graph.gexf')
# Out:
# ...
# 100%|██████████| 569/569 [00:00<00:00, 50622.75it/s]
# Started kNN of data on pivots...
# Finished kNN of data on pivots in  0.0023870468139648438  secs
# Started spring strength computation between pivots...
# Finished spring strength computation in  0.041970014572143555  secs
# Started kNN graph computation from lil_matrix...
# Finished kNN graph of pivots in  0.017010927200317383  secs
# Preparing networkx graph...
# Finished preparing networkx graph in  0.004163026809692383  secs
# Saved gexf file

# %%
springyknn.viz_spring_graph(G, dim=2, iterations=150, scale=1.0)
# Out:
# Preparing networkx visualization...
# Computing circular layout positions...
# Finished computing circular layout positions in  0.0014629364013671875  secs
# Computing spring layout positions...
# Finished computing spring layout positions in  18.664968013763428  secs
# <img src="data:image/png;base64,..." width="640">
# Finished networkx visualization in  21.130340099334717  secs
