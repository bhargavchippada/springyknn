# %%
from springyknn.springyknn import *

# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
from sklearn.datasets import load_iris
x_train, y_train = load_iris(True)
y_train = y_train.reshape(-1,1)
print(x_train.shape)
print(y_train.shape)
# Out:
# (150, 4)
# (150, 1)

# %%
springyknn = SpringyKNN(x_train, y_train, randomize=True, num_pivots=150)
G = springyknn.get_springy_knn_graph(k1=5, k2=5)
springyknn.write_gexf(G, filename='iris_springyknn_graph.gexf')
# Out:
# 100%|██████████| 150/150 [00:00<00:00, 3495.70it/s]
# 100%|██████████| 150/150 [00:00<00:00, 16402.37it/s]
# Started kNN of data on pivots...
# Finished kNN of data on pivots in  0.002391815185546875  secs
# Started spring strength computation between pivots...
# Finished spring strength computation in  0.04811811447143555  secs
# Started kNN graph computation from lil_matrix...
# Finished kNN graph of pivots in  0.02117300033569336  secs
# Preparing networkx graph...
# Finished preparing networkx graph in  0.005415916442871094  secs
# Saved gexf file

# %%
springyknn.viz_spring_graph(G, dim=2, iterations=150, scale=1.0)
# Out:
# Preparing networkx visualization...
# Computing circular layout positions...
# Finished computing circular layout positions in  0.0006158351898193359  secs
# Computing spring layout positions...
# Finished computing spring layout positions in  0.15104222297668457  secs
# <img src="data:image/png;base64,..." width="640">
# Finished networkx visualization in  0.49353599548339844  secs
